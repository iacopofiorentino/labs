# %% [markdown]
# # lab 12
#
# Explore migration-related databy  interpreting some of the metrics. Along are presented some forms of calculating relevant metrics.
#
# data: migracoes2015.csv
#
# You may use, for example:
#
# •	Slides of the course
#
# •	https://networkx.github.io/documentation/stable/ (https://networkx.github.io/documentation/stable/
#
# •	https://www.analyticsvidhya.com/blog/2018/04/introduction-to-graph-theorynetwork-analysis-python-codes/

# %%
#libraries that you may use
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
G = nx.DiGraph()

G.add_edge(a,b, weight= c)

for a,b,c in zip(df.origem, df.destino, df.numeros):
       G.add_edge(a,b, weight= c)

G.degree(weight='weight')
degree=G.degree()

#dictionary with degrees
degree_values = dict(degree).values()
G.nodes
G.edges

#draw chart
nx.draw(G, dim=100, with_labels=True)

#or
plt.figure(figsize=(20, 20))
po1 = nx.spring_layout(G,scale=2)
nx.draw(G, node_size=10, pos=po1, edge_color='y', label='r', with_labels=True)
plt.show()

#or for po1 and po1 = nx.random_layout(G)
degree =[deg for node, deg in nx.degree(G)]
max(degree)
min(degree)
kavg = np.mean(degrees)
print(kavg)

#convert directed to undirected
G1 = G.to_undirected()
Coeficiente de clustering
nx.clustering(G1)

#clioseness centrality
nx.closeness_centrality(G)

#eigenvector centrality
nx.eigenvector_centrality(G)

#degree centrality
nx.degree_centrality(G)

#number of linked components
nx.number_connected_components(G1)

#node linked to component
nx.node_connected_component(G1, 'João')

# %%
#libraries that you may use
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("migracoes2015.csv")

# %%
df.head()
# Out:
#        origem               destino   numeros
# 0      Mexico                   USA  12050031
# 1       India  United Arab Emirates   3499337
# 2      Russia               Ukraine   3276758
# 3     Ukraine                Russia   3269992
# 4  Bangladesh                 India   3171022

# %%
G = nx.DiGraph()

# %%
a=1
b=1
c=1

G.add_edge(a,b, weight= c)

for a,b,c in zip(df.origem, df.destino, df.numeros):
       G.add_edge(a,b, weight= c)

G.degree(weight='weight')
degree=G.degree()
print(degree)
# Out:
# [(1, 2), ('Mexico', 462), ('USA', 462), ('India', 462), ('United Arab Emirates', 462), ('Russia', 462), ('Ukraine', 462), ('Bangladesh', 462), ('Kazakhstan', 462), ('Afghanistan', 462), ('Iran', 462), ('China', 462), ('ChinaHK', 462), ('Palestine', 462), ('Jordan', 462), ('Pakistan', 462), ('Myanmar', 462), ('Thailand', 462), ('Poland', 462), ('Germany', 462), ('Philippines', 462), ('Saudi Arabia', 462), ('Puerto Rico', 462), ('Turkey', 462), ('Syria', 462), ('Algeria', 462), ('France', 462), ('Viet Nam', 462), ('Burkina Faso', 462), ("Côte d'Ivoire", 462), ('Indonesia', 462), ('UK', 462), ('Australia', 462), ('El Salvador', 462), ('Lebanon', 462), ('Uzbekistan', 462), ('Cuba', 462), ('Malaysia', 462), ('Singapore', 462), ('South Korea', 462), ('Kuwait', 462), ('Romania', 462), ('Italy', 462), ('Colombia', 462), ('Venezuela', 462), ('Lao', 462), ('Dominican Republic', 462), ('Egypt', 462), ('Morocco', 462), ('Guatemala', 462), ('Canada', 462), ('Cambodia', 462), ('Oman', 462), ('Azerbaijan', 462), ('Belarus', 462), ('Portugal', 462), ('Jamaica', 462), ('Spain', 462), ('Paraguay', 462), ('Argentina', 462), ('Japan', 462), ('Qatar', 462), ('New Zealand', 462), ('Haiti', 462), ('Kyrgyzstan', 462), ('Yemen', 462), ('Sudan', 462), ('South Sudan', 462), ('Czech Republic', 462), ('Nepal', 462), ('Honduras', 462), ('Armenia', 462), ('Ireland', 462), ('Somalia', 462), ('Kenya', 462), ('Bulgaria', 462), ('Zimbabwe', 462), ('South Africa', 462), ('Tajikistan', 462), ('Georgia', 462), ('Mozambique', 462), ('Albania', 462), ('Ethiopia', 462), ('Ecuador', 462), ('Peru', 462), ('Greece', 462), ('Bolivia', 462), ('Bosnia and Herzegovina', 462), ('Croatia', 462), ('Sri Lanka', 462), ('Tunisia', 462), ('Chad', 462), ('Switzerland', 462), ('Mali', 462), ('Benin', 462), ('Nigeria', 462), ('Lesotho', 462), ('Brazil', 462), ('Serbia', 462), ('Uganda', 462), ('Congo', 462), ('Bahrain', 462), ('Nicaragua', 462), ('Costa Rica', 462), ('Moldova', 462), ('Libya', 462), ('China Macao', 462), ('Guyana', 462), ('Austria', 462), ('Iraq', 462), ('Trinidad and Tobago', 462), ('Rwanda', 462), ('Ghana', 462), ('Chile', 462), ('Hungary', 462), ('Central African Republic', 462), ('Cameroon', 462), ('Netherlands', 462), ('Suriname', 462), ('Turkmenistan', 462), ('Angola', 462), ('Belgium', 462), ('Burundi', 462), ('Israel', 462), ('Finland', 462), ('Sweden', 462), ('Eritrea', 462), ('Togo', 462), ('Macedonia', 462), ('Estonia', 462), ('Latvia', 462), ('Namibia', 462), ('Uruguay', 462), ('Madagascar', 462), ('Senegal', 462), ('Gambia', 462), ('Lithuania', 462), ('Niger', 462), ('Panama', 462), ('Slovenia', 462), ('Malawi', 462), ('Guinea', 462), ('Luxembourg', 462), ('Djibouti', 462), ('Swaziland', 462), ('Norway', 462), ('Western Sahara', 462), ('Slovakia', 462), ('Tanzania', 462), ('Cyprus', 462), ('Réunion', 462), ('Liberia', 462), ('Fiji', 462), ('Montenegro', 462), ('Sierra Leone', 462), ('North Korea', 462), ('Curaçao', 462), ('Zambia', 462), ('Comoros', 462), ('Mayotte', 462), ('Channel Islands', 462), ('Cabo Verde', 462), ('Mauritania', 462), ('Equatorial Guinea', 462), ('Gabon', 462), ('Guadeloupe', 462), ('Barbados', 462), ('Maldives', 462), ('Samoa', 462), ('Belize', 462), ('Malta', 462), ('Brunei Darussalam', 462), ('Martinique', 462), ('Mauritius', 462), ('Botswana', 462), ('Bhutan', 462), ('Denmark', 462), ('Isle of Man', 462), ('New Caledonia', 462), ('Bahamas', 462), ('Grenada', 462), ('French Guiana', 462), ('Dominica', 462), ('Guam', 462), ('Antigua and Barbuda', 462), ('Guinea-Bissau', 462), ('Monaco', 462), ('Tonga', 462), ('Saint Vincent and the Grenadines', 462), ('Timor-Leste', 462), ('Sint Maarten (Dutch part)', 462), ('Mongolia', 462), ('Saint Lucia', 462), ('French Polynesia', 462), ('Andorra', 462), ('Sao Tome and Principe', 462), ('Saint Kitts and Nevis', 462), ('United States Virgin Islands', 462), ('Greenland', 462), ('American Samoa', 462), ('Cook Islands', 462), ('Liechtenstein', 462), ('Faeroe Islands', 462), ('Gibraltar', 462), ('N ...

# %%
for a,b,c in zip(df.origem, df.destino, df.numeros):
  if c>500000:
   G.add_edge(a,b, weight= c)

degree(weight='weight')
degree=G.degree()
print(degree)
# Out:
# [('Mexico', 2), ('USA', 19), ('India', 12), ('United Arab Emirates', 5), ('Russia', 12), ('Ukraine', 2), ('Bangladesh', 3), ('Kazakhstan', 3), ('Afghanistan', 2), ('Iran', 1), ('China', 5), ('ChinaHK', 1), ('Palestine', 2), ('Jordan', 2), ('Pakistan', 6), ('Myanmar', 1), ('Thailand', 3), ('Poland', 2), ('Germany', 7), ('Philippines', 3), ('Saudi Arabia', 7), ('Puerto Rico', 1), ('Turkey', 2), ('Syria', 4), ('Algeria', 1), ('France', 3), ('Viet Nam', 1), ('Burkina Faso', 2), ("Côte d'Ivoire", 2), ('Indonesia', 2), ('UK', 7), ('Australia', 2), ('El Salvador', 1), ('Lebanon', 2), ('Uzbekistan', 2), ('Cuba', 1), ('Malaysia', 2), ('Singapore', 1), ('South Korea', 3), ('Kuwait', 1), ('Romania', 3), ('Italy', 1), ('Colombia', 2), ('Venezuela', 1), ('Lao', 1), ('Dominican Republic', 1), ('Egypt', 2), ('Morocco', 2), ('Guatemala', 1), ('Canada', 5), ('Cambodia', 1), ('Oman', 1), ('Azerbaijan', 1), ('Belarus', 2), ('Portugal', 1), ('Jamaica', 1), ('Spain', 2), ('Paraguay', 1), ('Argentina', 1), ('Japan', 2), ('Qatar', 1), ('New Zealand', 1), ('Haiti', 1), ('Kyrgyzstan', 1), ('Yemen', 1), ('Sudan', 1), ('South Sudan', 1), ('Czech Republic', 1), ('Nepal', 1), ('Honduras', 1), ('Armenia', 1), ('Ireland', 1)]

# %%
nx.draw(G, dim=100, with_labels=True)
# Out:
# //anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# //anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
#or
plt.figure(figsize=(20, 20))
po1 = nx.spring_layout(G,scale=2)
nx.draw(G, node_size=10, pos=po1, edge_color='y', label='r', with_labels=True)
plt.show()

# %%
#or for po1 and po1 = nx.random_layout(G)
degree =[deg for node, deg in nx.degree(G)]
max(degree)
min(degree)
kavg = np.mean(degree)
print(kavg)
# Out:
# 2.5555555555555554

# %%
#convert directed to undirected
G1 = G.to_undirected()
#Coeficiente de clustering
nx.clustering(G1)
# Out:
# {'Mexico': 0,
#  'USA': 0.0392156862745098,
#  'India': 0.14545454545454545,
#  'United Arab Emirates': 0.2,
#  'Russia': 0.03571428571428571,
#  'Ukraine': 0,
#  'Bangladesh': 0.6666666666666666,
#  'Kazakhstan': 1.0,
#  'Afghanistan': 0,
#  'Iran': 0,
#  'China': 0.3,
#  'ChinaHK': 0,
#  'Palestine': 0,
#  'Jordan': 0,
#  'Pakistan': 0.3,
#  'Myanmar': 0,
#  'Thailand': 0,
#  'Poland': 0,
#  'Germany': 0.047619047619047616,
#  'Philippines': 0.3333333333333333,
#  'Saudi Arabia': 0.09523809523809523,
#  'Puerto Rico': 0,
#  'Turkey': 0,
#  'Syria': 0,
#  'Algeria': 0,
#  'France': 0,
#  'Viet Nam': 0,
#  'Burkina Faso': 0,
#  "Côte d'Ivoire": 0,
#  'Indonesia': 0,
#  'UK': 0.19047619047619047,
#  'Australia': 0,
#  'El Salvador': 0,
#  'Lebanon': 0,
#  'Uzbekistan': 0,
#  'Cuba': 0,
#  'Malaysia': 0,
#  'Singapore': 0,
#  'South Korea': 0.6666666666666666,
#  'Kuwait': 0,
#  'Romania': 0,
#  'Italy': 0,
#  'Colombia': 0,
#  'Venezuela': 0,
#  'Lao': 0,
#  'Dominican Republic': 0,
#  'Egypt': 0,
#  'Morocco': 0,
#  'Guatemala': 0,
#  'Canada': 0.5,
#  'Cambodia': 0,
#  'Oman': 0,
#  'Azerbaijan': 0,
#  'Belarus': 0,
#  'Portugal': 0,
#  'Jamaica': 0,
#  'Spain': 0,
#  'Paraguay': 0,
#  'Argentina': 0,
#  'Japan': 1.0,
#  'Qatar': 0,
#  'New Zealand': 0,
#  'Haiti': 0,
#  'Kyrgyzstan': 0,
#  'Yemen': 0,
#  'Sudan': 0,
#  'South Sudan': 0,
#  'Czech Republic': 0,
#  'Nepal': 0,
#  'Honduras': 0,
#  'Armenia': 0,
#  'Ireland': 0}

# %%
#clioseness centrality
nx.closeness_centrality(G)
# Out:
# {'Mexico': 0.18818063017278933,
#  'USA': 0.2944116310767833,
#  'India': 0.04507042253521127,
#  'United Arab Emirates': 0.07668231611893583,
#  'Russia': 0.09859154929577464,
#  'Ukraine': 0.05308775731310942,
#  'Bangladesh': 0.0,
#  'Kazakhstan': 0.05308775731310942,
#  'Afghanistan': 0.0,
#  'Iran': 0.014084507042253521,
#  'China': 0.0,
#  'ChinaHK': 0.014084507042253521,
#  'Palestine': 0.0,
#  'Jordan': 0.028169014084507043,
#  'Pakistan': 0.03755868544600939,
#  'Myanmar': 0.0,
#  'Thailand': 0.04225352112676056,
#  'Poland': 0.0,
#  'Germany': 0.11901408450704226,
#  'Philippines': 0.0,
#  'Saudi Arabia': 0.10371318822023048,
#  'Puerto Rico': 0.0,
#  'Turkey': 0.014084507042253521,
#  'Syria': 0.0,
#  'Algeria': 0.0,
#  'France': 0.04225352112676056,
#  'Viet Nam': 0.0,
#  'Burkina Faso': 0.014084507042253521,
#  "Côte d'Ivoire": 0.014084507042253521,
#  'Indonesia': 0.0,
#  'UK': 0.06901408450704224,
#  'Australia': 0.060044477390659746,
#  'El Salvador': 0.0,
#  'Lebanon': 0.028169014084507043,
#  'Uzbekistan': 0.05308775731310942,
#  'Cuba': 0.0,
#  'Malaysia': 0.014084507042253521,
#  'Singapore': 0.018779342723004695,
#  'South Korea': 0.014084507042253521,
#  'Kuwait': 0.035211267605633804,
#  'Romania': 0.0,
#  'Italy': 0.014084507042253521,
#  'Colombia': 0.0,
#  'Venezuela': 0.014084507042253521,
#  'Lao': 0.0,
#  'Dominican Republic': 0.0,
#  'Egypt': 0.0,
#  'Morocco': 0.0,
#  'Guatemala': 0.0,
#  'Canada': 0.08285004142502071,
#  'Cambodia': 0.0,
#  'Oman': 0.035211267605633804,
#  'Azerbaijan': 0.0,
#  'Belarus': 0.05308775731310942,
#  'Portugal': 0.0,
#  'Jamaica': 0.0,
#  'Spain': 0.028169014084507043,
#  'Paraguay': 0.0,
#  'Argentina': 0.014084507042253521,
#  'Japan': 0.028169014084507043,
#  'Qatar': 0.035211267605633804,
#  'New Zealand': 0.0,
#  'Haiti': 0.0,
#  'Kyrgyzstan': 0.0,
#  'Yemen': 0.0,
#  'Sudan': 0.0,
#  'South Sudan': 0.014084507042253521,
#  'Czech Republic': 0.0,
#  'Nepal': 0.0,
#  'Honduras': 0.0,
#  'Armenia': 0.0,
#  'Ireland': 0.0}

# %%
#eigenvector centrality
nx.eigenvector_centrality(G)
# Out:
# {'Mexico': 0.147473187325021,
#  'USA': 0.29491489531703285,
#  'India': 6.750393068309751e-07,
#  'United Arab Emirates': 1.3500786136305163e-06,
#  'Russia': 0.5897587314963653,
#  'Ukraine': 0.2948793657481827,
#  'Bangladesh': 1.5716983630477734e-17,
#  'Kazakhstan': 0.2948793657481827,
#  'Afghanistan': 1.5716983630477734e-17,
#  'Iran': 5.500944270667206e-16,
#  'China': 1.5716983630477734e-17,
#  'ChinaHK': 5.500944270667206e-16,
#  'Palestine': 1.5716983630477734e-17,
#  'Jordan': 1.0844718705029634e-15,
#  'Pakistan': 6.750393068152582e-07,
#  'Myanmar': 1.5716983630477734e-17,
#  'Thailand': 1.6188493139392067e-15,
#  'Poland': 1.5716983630477734e-17,
#  'Germany': 0.44231904862228455,
#  'Philippines': 1.5716983630477734e-17,
#  'Saudi Arabia': 1.3500786146992714e-06,
#  'Puerto Rico': 1.5716983630477734e-17,
#  'Turkey': 5.500944270667206e-16,
#  'Syria': 1.5716983630477734e-17,
#  'Algeria': 1.5716983630477734e-17,
#  'France': 1.6188493139392067e-15,
#  'Viet Nam': 1.5716983630477734e-17,
#  'Burkina Faso': 2.7001572273867686e-07,
#  "Côte d'Ivoire": 2.7001572273867686e-07,
#  'Indonesia': 1.5716983630477734e-17,
#  'UK': 1.350078613096139e-06,
#  'Australia': 1.3500786032101559e-06,
#  'El Salvador': 1.5716983630477734e-17,
#  'Lebanon': 1.0844718705029634e-15,
#  'Uzbekistan': 0.2948793657481827,
#  'Cuba': 1.5716983630477734e-17,
#  'Malaysia': 5.500944270667206e-16,
#  'Singapore': 9.367322243764726e-15,
#  'South Korea': 5.500944270667206e-16,
#  'Kuwait': 6.750393062808806e-07,
#  'Romania': 1.5716983630477734e-17,
#  'Italy': 5.500944270667206e-16,
#  'Colombia': 1.5716983630477734e-17,
#  'Venezuela': 5.500944270667206e-16,
#  'Lao': 1.5716983630477734e-17,
#  'Dominican Republic': 1.5716983630477734e-17,
#  'Egypt': 1.5716983630477734e-17,
#  'Morocco': 1.5716983630477734e-17,
#  'Guatemala': 1.5716983630477734e-17,
#  'Canada': 2.025117910009697e-06,
#  'Cambodia': 1.5716983630477734e-17,
#  'Oman': 6.750393062808806e-07,
#  'Azerbaijan': 1.5716983630477734e-17,
#  'Belarus': 0.2948793657481827,
#  'Portugal': 1.5716983630477734e-17,
#  'Jamaica': 1.5716983630477734e-17,
#  'Spain': 1.0844718705029634e-15,
#  'Paraguay': 1.5716983630477734e-17,
#  'Argentina': 5.500944270667206e-16,
#  'Japan': 9.901699687200972e-15,
#  'Qatar': 6.750393062808806e-07,
#  'New Zealand': 1.5716983630477734e-17,
#  'Haiti': 1.5716983630477734e-17,
#  'Kyrgyzstan': 1.5716983630477734e-17,
#  'Yemen': 1.5716983630477734e-17,
#  'Sudan': 1.5716983630477734e-17,
#  'South Sudan': 5.500944270667206e-16,
#  'Czech Republic': 1.5716983630477734e-17,
#  'Nepal': 1.5716983630477734e-17,
#  'Honduras': 1.5716983630477734e-17,
#  'Armenia': 1.5716983630477734e-17,
#  'Ireland': 1.5716983630477734e-17}

# %%
#degree centrality
nx.degree_centrality(G)
# Out:
# {'Mexico': 0.028169014084507043,
#  'USA': 0.26760563380281693,
#  'India': 0.16901408450704225,
#  'United Arab Emirates': 0.07042253521126761,
#  'Russia': 0.16901408450704225,
#  'Ukraine': 0.028169014084507043,
#  'Bangladesh': 0.04225352112676056,
#  'Kazakhstan': 0.04225352112676056,
#  'Afghanistan': 0.028169014084507043,
#  'Iran': 0.014084507042253521,
#  'China': 0.07042253521126761,
#  'ChinaHK': 0.014084507042253521,
#  'Palestine': 0.028169014084507043,
#  'Jordan': 0.028169014084507043,
#  'Pakistan': 0.08450704225352113,
#  'Myanmar': 0.014084507042253521,
#  'Thailand': 0.04225352112676056,
#  'Poland': 0.028169014084507043,
#  'Germany': 0.09859154929577466,
#  'Philippines': 0.04225352112676056,
#  'Saudi Arabia': 0.09859154929577466,
#  'Puerto Rico': 0.014084507042253521,
#  'Turkey': 0.028169014084507043,
#  'Syria': 0.056338028169014086,
#  'Algeria': 0.014084507042253521,
#  'France': 0.04225352112676056,
#  'Viet Nam': 0.014084507042253521,
#  'Burkina Faso': 0.028169014084507043,
#  "Côte d'Ivoire": 0.028169014084507043,
#  'Indonesia': 0.028169014084507043,
#  'UK': 0.09859154929577466,
#  'Australia': 0.028169014084507043,
#  'El Salvador': 0.014084507042253521,
#  'Lebanon': 0.028169014084507043,
#  'Uzbekistan': 0.028169014084507043,
#  'Cuba': 0.014084507042253521,
#  'Malaysia': 0.028169014084507043,
#  'Singapore': 0.014084507042253521,
#  'South Korea': 0.04225352112676056,
#  'Kuwait': 0.014084507042253521,
#  'Romania': 0.04225352112676056,
#  'Italy': 0.014084507042253521,
#  'Colombia': 0.028169014084507043,
#  'Venezuela': 0.014084507042253521,
#  'Lao': 0.014084507042253521,
#  'Dominican Republic': 0.014084507042253521,
#  'Egypt': 0.028169014084507043,
#  'Morocco': 0.028169014084507043,
#  'Guatemala': 0.014084507042253521,
#  'Canada': 0.07042253521126761,
#  'Cambodia': 0.014084507042253521,
#  'Oman': 0.014084507042253521,
#  'Azerbaijan': 0.014084507042253521,
#  'Belarus': 0.028169014084507043,
#  'Portugal': 0.014084507042253521,
#  'Jamaica': 0.014084507042253521,
#  'Spain': 0.028169014084507043,
#  'Paraguay': 0.014084507042253521,
#  'Argentina': 0.014084507042253521,
#  'Japan': 0.028169014084507043,
#  'Qatar': 0.014084507042253521,
#  'New Zealand': 0.014084507042253521,
#  'Haiti': 0.014084507042253521,
#  'Kyrgyzstan': 0.014084507042253521,
#  'Yemen': 0.014084507042253521,
#  'Sudan': 0.014084507042253521,
#  'South Sudan': 0.014084507042253521,
#  'Czech Republic': 0.014084507042253521,
#  'Nepal': 0.014084507042253521,
#  'Honduras': 0.014084507042253521,
#  'Armenia': 0.014084507042253521,
#  'Ireland': 0.014084507042253521}

# %%
#number of linked components
nx.number_connected_components(G1)
# Out:
# 5

# %%
#node linked to component
nx.node_connected_component(G1, 'USA')
# Out:
# {'Afghanistan',
#  'Algeria',
#  'Armenia',
#  'Australia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belarus',
#  'Canada',
#  'China',
#  'ChinaHK',
#  'Colombia',
#  'Cuba',
#  'Czech Republic',
#  'Dominican Republic',
#  'Egypt',
#  'El Salvador',
#  'France',
#  'Germany',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Lebanon',
#  'Malaysia',
#  'Mexico',
#  'Morocco',
#  'Nepal',
#  'New Zealand',
#  'Oman',
#  'Pakistan',
#  'Palestine',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Saudi Arabia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Syria',
#  'Turkey',
#  'UK',
#  'USA',
#  'Ukraine',
#  'United Arab Emirates',
#  'Uzbekistan',
#  'Venezuela',
#  'Viet Nam',
#  'Yemen'}
