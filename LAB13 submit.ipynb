# %%
Pokemon Go is an augmented reality game developed by Nantic, Inc for Android and iOS. In this
game, there are beings called Pokemons that can be captured by players. These beings can still be
used to play with others in gyms. The 'pokemon.csv' file displays data about Pokemons. Each line
represents a pokemon, including the following data:
MAX_HP -Max of life
MAX_ATT- Max damage
MAX_DEF -Max defense
MAX_CP - Max power of combat
CATCH_RATE - Probability of catching
ESCAPE_RATE - probability of escaping
Type 1 -
Type 2 -
You can:
Identify how many types 1 types 2 are there?
Create an explanatory model that the "target" is the "Max Power of Combat". Choose the features. It
is suggested: Maximo of life, maximum damage and maximum defense. Use multiple models,
including regressions.
Analyze whether intendant variables should be eliminated. For example, if they have reduced
variability or if they are too correlated with each other.  







#libraries that you may use
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_csv("pokemon2.csv")

# %%
df.head()
# Out:
#    # NAME_ENGLISH NAME_GERMAN NAME_FRENCH   NAME_JAPAN   NAME_KOREAN   TYP1  \
# 0  1    Bulbasaur     Bisasam  Bulbizarre  Fushigidane   Isanghaessi  Grass
# 1  2      Ivysaur   Bisaknosp  Herbizarre   Fushigisou   Isanghaepul  Grass
# 2  3     Venusaur    Bisaflor  Florizarre  Fushigibana  Isanghaekkot  Grass
# 3  4   Charmander    Glumanda   Salamèche     Hitokage         Pairi   Fire
# 4  5   Charmeleon     Glutexo   Reptincel      Lizardo       Rijadeu   Fire
#
#      TYP2  GENERATION  CANDY  BUDDY_DISTANCE  MAX_HP  MAX_ATT  MAX_DEF  \
# 0  Poison         1.0   25.0             3.0   128.0    118.0    111.0
# 1  Poison         1.0  100.0             3.0   155.0    151.0    143.0
# 2  Poison         1.0    NaN             3.0   190.0    198.0    189.0
# 3     NaN         1.0   25.0             3.0   118.0    116.0     93.0
# 4     NaN         1.0  100.0             3.0   151.0    158.0    126.0
#
#    MAX_CP CATCH_RATE ESCAPE_RATE SHINY       ICON_PATH        SPRITE_PATH
# 0  1115.0    20,00 %     10,00 %   Yes  ./icon/001.png  ./sprites/001.png
# 1  1699.0    10,00 %      7,00 %   Yes  ./icon/002.png  ./sprites/002.png
# 2  2720.0     5,00 %      5,00 %   Yes  ./icon/003.png  ./sprites/003.png
# 3   980.0    20,00 %     10,00 %   Yes  ./icon/004.png  ./sprites/004.png
# 4  1653.0    10,00 %      7,00 %   Yes  ./icon/005.png  ./sprites/005.png

# %%
df.dtypes
# Out:
# #                  object
# NAME_ENGLISH       object
# NAME_GERMAN        object
# NAME_FRENCH        object
# NAME_JAPAN         object
# NAME_KOREAN        object
# TYP1               object
# TYP2               object
# GENERATION        float64
# CANDY             float64
# BUDDY_DISTANCE    float64
# MAX_HP            float64
# MAX_ATT           float64
# MAX_DEF           float64
# MAX_CP            float64
# CATCH_RATE         object
# ESCAPE_RATE        object
# SHINY              object
# ICON_PATH          object
# SPRITE_PATH        object
# dtype: object

# %%
G = nx.Graph()
G.add_nodes_from(df.NAME_ENGLISH)

# %%
len(G) #number of nodes
# Out:
# 809

# %%
nx.draw(G, dim=100, with_labels=True)

# %%
df.shape
# Out:
# (842, 20)

# %%
df1=df.dropna() #erase the N/A values

# %%
df1.head()
# Out:
#      # NAME_ENGLISH NAME_GERMAN NAME_FRENCH   NAME_JAPAN  NAME_KOREAN    TYP1  \
# 0    1    Bulbasaur     Bisasam  Bulbizarre  Fushigidane  Isanghaessi   Grass
# 1    2      Ivysaur   Bisaknosp  Herbizarre   Fushigisou  Isanghaepul   Grass
# 12  13       Weedle     Hornliu     Aspicot       Beedle   Ppulchungi     Bug
# 13  14       Kakuna      Kokuna   Coconfort       Cocoon   Ttakchungi     Bug
# 15  16       Pidgey      Taubsi     Roucool        Poppo         Gugu  Normal
#
#       TYP2  GENERATION  CANDY  BUDDY_DISTANCE  MAX_HP  MAX_ATT  MAX_DEF  \
# 0   Poison         1.0   25.0             3.0   128.0    118.0    111.0
# 1   Poison         1.0  100.0             3.0   155.0    151.0    143.0
# 12  Poison         1.0   12.0             1.0   120.0     63.0     50.0
# 13  Poison         1.0   50.0             1.0   128.0     46.0     75.0
# 15  Flying         1.0   12.0             1.0   120.0     85.0     73.0
#
#     MAX_CP CATCH_RATE ESCAPE_RATE SHINY       ICON_PATH        SPRITE_PATH
# 0   1115.0    20,00 %     10,00 %   Yes  ./icon/001.png  ./sprites/001.png
# 1   1699.0    10,00 %      7,00 %   Yes  ./icon/002.png  ./sprites/002.png
# 12   456.0    50,00 %     20,00 %    No  ./icon/013.png  ./sprites/013.png
# 13   432.0    25,00 %      9,00 %    No  ./icon/014.png  ./sprites/014.png
# 15   680.0    50,00 %     20,00 %    No  ./icon/016.png  ./sprites/016.png

# %%
H = nx.Graph()
H.add_nodes_from(df1.NAME_ENGLISH)
len(H)
# Out:
# 91

# %%
H.number_of_edges() # interpretation: simple connection between 2 nodes
# Out:
# 0

# %%
a=1
b=2
c=3
H.add_edge(a,b, weight= c)

for a,b,c in zip(df1.NAME_ENGLISH,df1.NAME_ENGLISH, df1.MAX_CP):
       H.add_edge(a,b, weight= c)

H.degree(weight='weight')
degree=H.degree()
print(degree) #degree definition: number of nodes, one node is connected to;
#only 2 connections - not relevant to further exploration
# Out:
# [('Bulbasaur', 2), ('Ivysaur', 2), ('Weedle', 2), ('Kakuna', 2), ('Pidgey', 2), ('Pidgeotto', 2), ('Spearow', 2), ('Jigglypuff', 2), ('Zubat', 2), ('Golbat', 2), ('Oddish', 2), ('Gloom', 2), ('Paras', 2), ('Venonat', 2), ('Bellsprout', 2), ('Weepinbell', 2), ('Tentacool', 2), ('Geodude', 2), ('Graveler', 2), ('Slowpoke', 2), ('Magnemite', 2), ('Doduo', 2), ('Gastly', 2), ('Haunter', 2), ('Onix', 2), ('Exeggcute', 2), ('Rhyhorn', 2), ('Rhydon', 2), ('Scyther', 2), ('Omanyte', 2), ('Kabuto', 2), ('Hoothoot', 2), ('Ledyba', 2), ('Spinarak', 2), ('Chinchou', 2), ('Togetic', 2), ('Natu', 2), ('Marill', 2), ('Hoppip', 2), ('Skiploom', 2), ('Wooper', 2), ('Murkrow', 2), ('Gligar', 2), ('Sneasel', 2), ('Swinub', 2), ('Houndour', 2), ('Larvitar', 2), ('Pupitar', 2), ('Combusken', 2), ('Marshtomp', 2), ('Lotad', 2), ('Lombre', 2), ('Nuzleaf', 2), ('Tailow', 2), ('Wingull', 2), ('Ralts', 2), ('Kirlia', 2), ('Surskit', 2), ('Nincada', 2), ('Azurill', 2), ('Aron', 2), ('Lairon', 2), ('Meditite', 2), ('Roselia', 2), ('Carvanha', 2), ('Numel', 2), ('Vibrava', 2), ('Swablu', 2), ('Barboach', 2), ('Baltoy', 2), ('Lileep', 2), ('Anorith', 2), ('Spheal', 2), ('Sealeo', 2), ('Beldum', 2), ('Metang', 2), ('Monferno', 2), ('Starly', 2), ('Staravia', 2), ('Budew', 2), ('Shieldon', 2), ('Combee', 2), ('Drifloon', 2), ('Stunky', 2), ('Bronzor', 2), ('Mime Jr.', 2), ('Gible', 2), ('Gabite', 2), ('Skorupi', 2), ('Croagunk', 2), ('Snover', 2), (1, 1), (2, 1)]

# %%
nx.draw(H, dim=100, with_labels=True)
# Out:
# //anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
plt.figure(figsize=(20, 20))
po1 = nx.spring_layout(H,scale=2)
nx.draw(H, node_size=10, pos=po1, edge_color='y', label='r', with_labels=True)
plt.show()
#network graph emphasizes conclusions above about the edges

# %%
df1.TYP1.unique() #which types1 are there
# Out:
# array(['Grass', 'Bug', 'Normal', 'Poison', 'Water', 'Rock', 'Electric',
#        'Ghost', 'Ground', 'Fairy', 'Psychic', 'Dark', 'Ice', 'Fire',
#        'Steel', 'Fighting', 'Dragon'], dtype=object)

# %%
len(df1.TYP1.unique()) #how many different types1 (numeric)
# Out:
# 17

# %%
YX=df1[['MAX_CP','MAX_HP','MAX_ATT','MAX_DEF']]

# %%
YX.head()
# Out:
#     MAX_CP  MAX_HP  MAX_ATT  MAX_DEF
# 0   1115.0   128.0    118.0    111.0
# 1   1699.0   155.0    151.0    143.0
# 12   456.0   120.0     63.0     50.0
# 13   432.0   128.0     46.0     75.0
# 15   680.0   120.0     85.0     73.0

# %%
Y=YX['MAX_CP']
X=YX[['MAX_HP','MAX_ATT','MAX_DEF']]

# %%
# plot the all the values of the model

import matplotlib.pyplot as plt 
plt.scatter(df1['MAX_CP'], df1['MAX_HP'], df1['MAX_ATT'], df1['MAX_DEF'])
plt.title('Pokemon Features')
plt.xlabel('Life time / Damage / Defense')
plt.ylabel('Power of Combat')
# Out:
# Text(0, 0.5, 'Power of Combat')

# %%
#Analysing the correlation between the variables
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[12, 12])
corr_mtx = YX.corr()
sns.heatmap(corr_mtx, xticklabels=corr_mtx.columns, yticklabels=corr_mtx.columns, annot=True, cmap='Blues')
plt.title('Correlation analysis')
plt.show()

#Correlations are low. no further adjustment to the model needed
